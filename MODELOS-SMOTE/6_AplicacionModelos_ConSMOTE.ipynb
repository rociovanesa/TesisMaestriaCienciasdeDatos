# %%
####################################################

#ahora aplicaremos SMOTE y agrego una nueva métrica 

####################################################

# %%
#svm 3
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, ConfusionMatrixDisplay
)
from imblearn.over_sampling import SMOTE, RandomOverSampler

# === 1. Datos ===
X = tfidf_dataframe_2.to_numpy()
y = data['SubRubro_encoded'].reset_index(drop=True)

# === 2. Modelo SVM con hiperparámetros ajustados ===
modelo = SVC(C=10, kernel='linear', gamma='scale')

# === 3. Validación cruzada ===
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

resultados = []
y_true_bin = []
y_pred_bin = []

inicio_total = time.time()

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), start=1):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    print(f"\nPliegue {fold}:")
    print(f"  Registros en entrenamiento: {len(train_idx)}")
    print(f"  Registros en prueba:        {len(test_idx)}")

    try:
        smote = SMOTE(k_neighbors=1, random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
        print(f"  Registros después de SMOTE: {len(X_train_res)}")
    except ValueError:
        print("⚠️ SMOTE no aplicable, usando RandomOverSampler")
        ros = RandomOverSampler(random_state=42)
        X_train_res, y_train_res = ros.fit_resample(X_train, y_train)

    inicio = time.time()
    modelo.fit(X_train_res, y_train_res)
    y_pred = modelo.predict(X_test)
    fin = time.time()

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_test, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    tiempo = fin - inicio

    resultados.append({
        'Pliegue': fold,
        'Accuracy': acc,
        'Precisión Weighted': prec,
        'Recall Macro': rec,
        'F1-Score Macro': f1_macro,
        'F1-Score Weighted': f1_weighted,
        'Tiempo (s)': tiempo
    })

    binaria = (y_pred == y_test).astype(int)
    y_true_bin.extend([1] * len(binaria))
    y_pred_bin.extend(binaria)

# === 4. Mostrar métricas ===
resultados_df = pd.DataFrame(resultados)
print("\n📊 Resultados por pliegue:")
print(resultados_df.round(4))

print("\n📈 Promedios globales:")
print(resultados_df.drop(columns="Pliegue").mean().to_frame().T.round(4))

fin_total = time.time()
print(f"\n⏱️ Tiempo total de ejecución: {round(fin_total - inicio_total, 2)} segundos")
# Out:
# Pliegue 1:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 2:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 3:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 4:
#   Registros en entrenamiento: 3127
#   Registros en prueba:        781
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 5:
#   Registros en entrenamiento: 3127
#   Registros en prueba:        781
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# 📊 Resultados por pliegue:
#    Pliegue  Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0        1    0.6253              0.7425        0.4774          0.4972
# 1        2    0.6765              0.7827        0.5295          0.5332
# 2        3    0.6624              0.7844        0.5640          0.5594
# 3        4    0.6389              0.7677        0.5136          0.5253
# 4        5    0.6799              0.7924        0.5591          0.5668
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.6682    808.2707
# 1             0.7142    807.2632
# 2             0.7091    744.6156
# 3             0.6859    724.9125
# 4             0.7241    757.1960
#
# 📈 Promedios globales:
#    Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0    0.6566              0.7739        0.5287          0.5364
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.7003    768.4516
#
# ⏱️ Tiempo total de ejecución: 3859.42 segundos

# %%
#random forest
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, ConfusionMatrixDisplay
)
from imblearn.over_sampling import SMOTE, RandomOverSampler

# === 1. Datos ===
X = tfidf_dataframe_2.to_numpy()
y_original = data['SubRubro_encoded'].reset_index(drop=True)

# Filtrar clases con al menos 2 ejemplos
conteo = y_original.value_counts()
clases_validas = conteo[conteo >= 2].index
mask = y_original.isin(clases_validas)
X = X[mask]
y = y_original[mask].reset_index(drop=True)

# === 2. Validación cruzada ===
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
resultados = []
y_true_bin = []
y_pred_bin = []

inicio_total = time.time()

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), start=1):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train_orig = y.iloc[train_idx].reset_index(drop=True)
    y_test_orig = y.iloc[test_idx].reset_index(drop=True)

    # Mapear las clases locales por pliegue
    clases_unicas = np.sort(y_train_orig.unique())
    clase_a_indice = {clase: i for i, clase in enumerate(clases_unicas)}
    y_train = y_train_orig.map(clase_a_indice)
    y_test = y_test_orig.map(clase_a_indice)

    # === Aplicar SMOTE o fallback a RandomOverSampler ===
    try:
        smote = SMOTE(k_neighbors=1, random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
        print(f"\nPliegue {fold}:")
        print(f"  Registros en entrenamiento antes de SMOTE: {len(X_train)}")
        print(f"  Registros después de SMOTE:                {len(X_train_res)}")
    except ValueError:
        print(f"\nPliegue {fold}: ⚠️ SMOTE no aplicable, usando RandomOverSampler")
        ros = RandomOverSampler(random_state=42)
        X_train_res, y_train_res = ros.fit_resample(X_train, y_train)

    print(f"  Registros en prueba:        {len(X_test)}")
    print(f"  Clases en pliegue:          {len(clases_unicas)}")

    modelo = RandomForestClassifier(
        n_estimators=100,
        max_depth=None,
        min_samples_split=5,
        min_samples_leaf=1,
        bootstrap=True,
        random_state=42,
        n_jobs=-1
    )

    inicio = time.time()
    modelo.fit(X_train_res, y_train_res)
    y_pred = modelo.predict(X_test)
    fin = time.time()

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_test, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    tiempo = fin - inicio

    resultados.append({
        'Pliegue': fold,
        'Accuracy': acc,
        'Precisión Weighted': prec,
        'Recall Macro': rec,
        'F1-Score Macro': f1_macro,
        'F1-Score Weighted': f1_weighted,
        'Tiempo (s)': tiempo
    })

    # Clasificación binaria: bien vs mal clasificado
    bien_clasificado = (y_pred == y_test).astype(int)
    y_true_bin.extend([1] * len(bien_clasificado))
    y_pred_bin.extend(bien_clasificado)

# === 3. Resultados promedio ===
resultados_df = pd.DataFrame(resultados)
print("\n📊 Resultados por pliegue:")
print(resultados_df.round(4))

print("\n📈 Promedios globales:")
print(resultados_df.drop(columns="Pliegue").mean().to_frame().T.round(4))

print(f"\n⏱️ Tiempo total: {round(time.time() - inicio_total, 2)} segundos")
# Out:
# Pliegue 1: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        780
#   Clases en pliegue:          105
#
# Pliegue 2: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        780
#   Clases en pliegue:          105
#
# Pliegue 3: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        779
#   Clases en pliegue:          105
#
# Pliegue 4: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        779
#   Clases en pliegue:          105
#
# Pliegue 5: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        779
#   Clases en pliegue:          105
#
# 📊 Resultados por pliegue:
#    Pliegue  Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0        1    0.6949              0.7301        0.5312          0.5149
# 1        2    0.7128              0.7502        0.6129          0.5953
# 2        3    0.6945              0.7457        0.5863          0.5549
# 3        4    0.6893              0.7422        0.5530          0.5453
# 4        5    0.7420              0.7765        0.6146          0.6008
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.7028    220.5112
# 1             0.7224    200.2666
# 2             0.7108    176.0152
# 3             0.7059    173.0222
# 4             0.7483    206.5922
#
# 📈 Promedios globales:
#    Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0    0.7067              0.7489        0.5796          0.5622
#
#    F1-Score Weighted  Tiempo (s)
# 0              0.718    195.2815
#
# ⏱️ Tiempo total: 990.98 segundos

# %%
#XBboots
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, ConfusionMatrixDisplay
)
from xgboost import XGBClassifier
from imblearn.over_sampling import SMOTE, RandomOverSampler

# === 1. Datos ===
X = tfidf_dataframe_2.to_numpy()
y_original = data['SubRubro_encoded'].reset_index(drop=True)

# Filtrar clases con al menos 2 ejemplos
conteo = y_original.value_counts()
clases_validas = conteo[conteo >= 2].index
mask = y_original.isin(clases_validas)
X = X[mask]
y = y_original[mask].reset_index(drop=True)

# === 2. Validación cruzada ===
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
resultados = []
y_true_bin = []
y_pred_bin = []

inicio_total = time.time()

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), start=1):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train_orig = y.iloc[train_idx].reset_index(drop=True)
    y_test_orig = y.iloc[test_idx].reset_index(drop=True)

    # Mapear clases locales
    clases_unicas = np.sort(y_train_orig.unique())
    clase_a_indice = {clase: i for i, clase in enumerate(clases_unicas)}
    y_train = y_train_orig.map(clase_a_indice)
    y_test = y_test_orig.map(clase_a_indice)

    # === Aplicar SMOTE o RandomOverSampler si hay clases con muy pocos ejemplos ===
    try:
        smote = SMOTE(k_neighbors=1, random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
        print(f"\nPliegue {fold}:")
        print(f"  Registros entrenamiento antes de SMOTE: {len(X_train)}")
        print(f"  Registros después de SMOTE:            {len(X_train_res)}")
    except ValueError:
        print(f"\nPliegue {fold}: ⚠️ SMOTE no aplicable, usando RandomOverSampler")
        ros = RandomOverSampler(random_state=42)
        X_train_res, y_train_res = ros.fit_resample(X_train, y_train)

    print(f"  Registros en prueba:        {len(X_test)}")
    print(f"  Clases en pliegue:          {len(clases_unicas)}")

    modelo = XGBClassifier(
        use_label_encoder=False,
        eval_metric='mlogloss',
        objective='multi:softmax',
        num_class=len(clases_unicas),
        colsample_bytree=0.8,
        gamma=0,
        learning_rate=0.2,
        max_depth=6,
        min_child_weight=1,
        n_estimators=50,
        reg_lambda=1,
        subsample=0.8,
        verbosity=0
    )

    inicio = time.time()
    modelo.fit(X_train_res, y_train_res)
    y_pred = modelo.predict(X_test)
    fin = time.time()

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_test, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    tiempo = fin - inicio

    resultados.append({
        'Pliegue': fold,
        'Accuracy': acc,
        'Precisión Weighted': prec,
        'Recall Macro': rec,
        'F1-Score Macro': f1_macro,
        'F1-Score Weighted': f1_weighted,
        'Tiempo (s)': tiempo
    })

    # Matriz binaria de aciertos vs errores
    binaria = (y_pred == y_test).astype(int)
    y_true_bin.extend([1] * len(binaria))
    y_pred_bin.extend(binaria)

# === 3. Mostrar métricas ===
resultados_df = pd.DataFrame(resultados)
print("\n📊 Resultados por pliegue:")
print(resultados_df.round(4))

print("\n📈 Promedios globales:")
print(resultados_df.drop(columns="Pliegue").mean().to_frame().T.round(4))

print(f"\n⏱️ Tiempo total: {round(time.time() - inicio_total, 2)} segundos")
# Out:
# Pliegue 1: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        780
#   Clases en pliegue:          105
#
# Pliegue 2: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        780
#   Clases en pliegue:          105
#
# Pliegue 3: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        779
#   Clases en pliegue:          105
#
# Pliegue 4: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        779
#   Clases en pliegue:          105
#
# Pliegue 5: ⚠️ SMOTE no aplicable, usando RandomOverSampler
#   Registros en prueba:        779
#   Clases en pliegue:          105
#
# 📊 Resultados por pliegue:
#    Pliegue  Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0        1    0.6026              0.6816        0.4783          0.4809
# 1        2    0.6192              0.7274        0.5554          0.5542
# 2        3    0.5982              0.6990        0.5051          0.4948
# 3        4    0.6008              0.6908        0.4960          0.4844
# 4        5    0.6573              0.7413        0.5571          0.5385
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.6255   1475.5731
# 1             0.6559   1590.4078
# 2             0.6363   1557.3148
# 3             0.6342   1539.7431
# 4             0.6840   1538.9722
#
# 📈 Promedios globales:
#    Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0    0.6156               0.708        0.5184          0.5105
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.6472   1540.4022
#
# ⏱️ Tiempo total: 7718.08 segundos

# %%
#knn
#En algunos pliegues, debido a la baja frecuencia de ciertas clases, SMOTE no pudo aplicarse 
#(por requerir al menos 2 muestras por clase). En esos casos se utilizó RandomOverSampler 
#como técnica de balanceo alternativa para permitir el entrenamiento del modelo sin interrupciones.
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, ConfusionMatrixDisplay
)
from imblearn.over_sampling import SMOTE, RandomOverSampler

# === 1. Datos ===
X = tfidf_dataframe_2.to_numpy()
y = data['SubRubro_encoded'].reset_index(drop=True)

# === 2. Definir modelo con mejores hiperparámetros ===
modelo = KNeighborsClassifier(n_neighbors=3, weights='distance', metric='euclidean')

# === 3. Validación cruzada ===
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

resultados = []
y_true_bin = []
y_pred_bin = []

inicio_total = time.time()

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), start=1):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    print(f"\nPliegue {fold}:")
    print(f"  Registros entrenamiento antes de SMOTE: {len(X_train)}")
    print(f"  Registros prueba:                       {len(X_test)}")

    # === Aplicar SMOTE (o RandomOverSampler si es necesario) ===
    try:
        smote = SMOTE(k_neighbors=1, random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
        print(f"  Registros entrenamiento después de SMOTE: {len(X_train_res)}")
    except ValueError:
        print(f"  ⚠️ SMOTE no aplicable, usando RandomOverSampler")
        ros = RandomOverSampler(random_state=42)
        X_train_res, y_train_res = ros.fit_resample(X_train, y_train)

    # === Entrenamiento y predicción ===
    inicio = time.time()
    modelo.fit(X_train_res, y_train_res)
    y_pred = modelo.predict(X_test)
    fin = time.time()

    # === Cálculo de métricas ===
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_test, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    tiempo = fin - inicio

    resultados.append({
        'Pliegue': fold,
        'Accuracy': acc,
        'Precisión Weighted': prec,
        'Recall Macro': rec,
        'F1-Score Macro': f1_macro,
        'F1-Score Weighted': f1_weighted,
        'Tiempo (s)': tiempo
    })

    # === Binaria: Bien vs Mal Clasificado ===
    binaria = (y_pred == y_test).astype(int)
    y_true_bin.extend([1] * len(binaria))  # se espera acertar (1)
    y_pred_bin.extend(binaria)             # 1 si acertó, 0 si falló

# === 4. Mostrar métricas ===
resultados_df = pd.DataFrame(resultados)
print("\n📊 Resultados por pliegue:")
print(resultados_df.round(4))

print("\n📈 Promedios globales:")
print(resultados_df.drop(columns="Pliegue").mean().to_frame().T.round(4))

fin_total = time.time()
print(f"\n⏱️ Tiempo total de ejecución: {round(fin_total - inicio_total, 2)} segundos")
# Out:
# Pliegue 1:
#   Registros entrenamiento antes de SMOTE: 3126
#   Registros prueba:                       782
#   ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 2:
#   Registros entrenamiento antes de SMOTE: 3126
#   Registros prueba:                       782
#   ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 3:
#   Registros entrenamiento antes de SMOTE: 3126
#   Registros prueba:                       782
#   ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 4:
#   Registros entrenamiento antes de SMOTE: 3127
#   Registros prueba:                       781
#   ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 5:
#   Registros entrenamiento antes de SMOTE: 3127
#   Registros prueba:                       781
#   ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# 📊 Resultados por pliegue:
#    Pliegue  Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0        1    0.5499              0.7999        0.4569          0.4888
# 1        2    0.5639              0.7992        0.4631          0.4931
# 2        3    0.5780              0.7805        0.5272          0.5386
# 3        4    0.5672              0.7939        0.4877          0.4957
# 4        5    0.6120              0.7887        0.5426          0.5630
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.6410      5.8466
# 1             0.6449      6.9028
# 2             0.6296      6.3129
# 3             0.6497      6.7649
# 4             0.6557      6.6302
#
# 📈 Promedios globales:
#    Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0    0.5742              0.7925        0.4955          0.5158
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.6442      6.4915
#
# ⏱️ Tiempo total de ejecución: 45.74 segundos

# %%
#Regresion logistica
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    precision_score, recall_score, f1_score, accuracy_score
)
from imblearn.over_sampling import SMOTE, RandomOverSampler

# === 1. Datos ===
X = tfidf_dataframe_2.to_numpy()
y = data['SubRubro_encoded'].reset_index(drop=True)

# === 2. Modelo con hiperparámetros ajustados ===
modelo = LogisticRegression(
    C=100,
    max_iter=500,
    multi_class='multinomial',
    penalty='l2',
    solver='saga'
)

kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

resultados = []
y_true_bin = []
y_pred_bin = []

inicio_total = time.time()

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), start=1):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    print(f"\nPliegue {fold}:")
    print(f"  Registros en entrenamiento: {len(X_train)}")
    print(f"  Registros en prueba:        {len(X_test)}")

    # === Aplicar SMOTE o RandomOverSampler ===
    try:
        smote = SMOTE(k_neighbors=1, random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
        print(f"  Registros después de SMOTE: {len(X_train_res)}")
    except ValueError:
        print("⚠️ SMOTE no aplicable, usando RandomOverSampler")
        ros = RandomOverSampler(random_state=42)
        X_train_res, y_train_res = ros.fit_resample(X_train, y_train)

    # === Entrenamiento y predicción ===
    inicio = time.time()
    modelo.fit(X_train_res, y_train_res)
    y_pred = modelo.predict(X_test)
    fin = time.time()

    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_test, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    tiempo = fin - inicio

    resultados.append({
        'Pliegue': fold,
        'Accuracy': acc,
        'Precisión Weighted': prec,
        'Recall Macro': rec,
        'F1-Score Macro': f1_macro,
        'F1-Score Weighted': f1_weighted,
        'Tiempo (s)': tiempo
    })

   
# === 3. Mostrar métricas ===
resultados_df = pd.DataFrame(resultados)
print("\n📊 Resultados por pliegue:")
print(resultados_df.round(4))

print("\n📈 Promedios globales:")
print(resultados_df.drop(columns="Pliegue").mean().to_frame().T.round(4))

fin_total = time.time()
print(f"\n⏱️ Tiempo total de ejecución: {round(fin_total - inicio_total, 2)} segundos")
# Out:
# Pliegue 1:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 2:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 3:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 4:
#   Registros en entrenamiento: 3127
#   Registros en prueba:        781
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 5:
#   Registros en entrenamiento: 3127
#   Registros en prueba:        781
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# 📊 Resultados por pliegue:
#    Pliegue  Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0        1    0.6841              0.7417        0.5175          0.5148
# 1        2    0.7199              0.7708        0.5797          0.5636
# 2        3    0.7136              0.7724        0.5890          0.5789
# 3        4    0.6812              0.7510        0.5284          0.5193
# 4        5    0.7324              0.7834        0.5895          0.5741
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.7013  81581.0997
# 1             0.7344  77059.5101
# 2             0.7356  92011.0487
# 3             0.7057  93789.4449
# 4             0.7492  84624.5336
#
# 📈 Promedios globales:
#    Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0    0.7062              0.7639        0.5608          0.5501
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.7252  85813.1274
#
# ⏱️ Tiempo total de ejecución: 429091.16 segundos

# %%
#prueba de modelo y matriz por clases.
#es para entender como se aplicar e lmodelo por clase.
import numpy as np
from sklearn.metrics import (
    confusion_matrix, classification_report,
    ConfusionMatrixDisplay
)
import matplotlib.pyplot as plt
import os

# Lista de clases únicas del dataset
clases = np.unique(y_test_total)

# Crear carpeta para guardar imágenes
carpeta_salida = "matrices_binarias_ovr"
os.makedirs(carpeta_salida, exist_ok=True)

for clase in clases:
    print(f"\n🔍 Evaluando Clase '{clase}' (One-vs-Rest)")

    # Etiquetas binarias para clase actual
    y_true_bin = (y_test_total == clase).astype(int)
    y_pred_bin = (y_pred_total == clase).astype(int)

    # Matriz de confusión binaria
    matriz_binaria = confusion_matrix(y_true_bin, y_pred_bin)

    # Mostrar matriz en consola
    print("                Predicho")
    print("               No    Sí")
    print(f"Real No     {matriz_binaria[0,0]}   {matriz_binaria[0,1]}")
    print(f"Real Sí     {matriz_binaria[1,0]}   {matriz_binaria[1,1]}")

    # Reporte de métricas
    print("\n📊 Métricas:")
    print(classification_report(
        y_true_bin, y_pred_bin,
        target_names=["No " + str(clase), str(clase)],
        zero_division=0
    ))

    # Mostrar y guardar el gráfico
    disp = ConfusionMatrixDisplay(
        confusion_matrix=matriz_binaria,
        display_labels=["No " + str(clase), str(clase)]
    )
    disp.plot(cmap='YlGnBu')
    plt.title(f"Matriz Binaria (Clase {clase} vs Resto)")
    plt.grid(False)

    # Guardar imagen
    nombre_archivo = os.path.join(carpeta_salida, f"matriz_binaria_clase_{clase}.png")
    plt.savefig(nombre_archivo, bbox_inches='tight')
    plt.close()

    print(f"✅ Imagen guardada en: {nombre_archivo}")
# Out:
# 🔍 Evaluando Clase '0' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3836   5
# Real Sí     35   32
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 0       0.99      1.00      0.99      3841
#            0       0.86      0.48      0.62        67
#
#     accuracy                           0.99      3908
#    macro avg       0.93      0.74      0.81      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_0.png
#
# 🔍 Evaluando Clase '1' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3903   1
# Real Sí     3   1
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 1       1.00      1.00      1.00      3904
#            1       0.50      0.25      0.33         4
#
#     accuracy                           1.00      3908
#    macro avg       0.75      0.62      0.67      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_1.png
#
# 🔍 Evaluando Clase '2' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3900   5
# Real Sí     3   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 2       1.00      1.00      1.00      3905
#            2       0.00      0.00      0.00         3
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_2.png
#
# 🔍 Evaluando Clase '3' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3709   29
# Real Sí     57   113
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 3       0.98      0.99      0.99      3738
#            3       0.80      0.66      0.72       170
#
#     accuracy                           0.98      3908
#    macro avg       0.89      0.83      0.86      3908
# weighted avg       0.98      0.98      0.98      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_3.png
#
# 🔍 Evaluando Clase '4' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3887   4
# Real Sí     12   5
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 4       1.00      1.00      1.00      3891
#            4       0.56      0.29      0.38        17
#
#     accuracy                           1.00      3908
#    macro avg       0.78      0.65      0.69      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_4.png
#
# 🔍 Evaluando Clase '5' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3898   1
# Real Sí     0   9
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 5       1.00      1.00      1.00      3899
#            5       0.90      1.00      0.95         9
#
#     accuracy                           1.00      3908
#    macro avg       0.95      1.00      0.97      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_5.png
#
# 🔍 Evaluando Clase '6' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3895   0
# Real Sí     5   8
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 6       1.00      1.00      1.00      3895
#            6       1.00      0.62      0.76        13
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.81      0.88      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_6.png
#
# 🔍 Evaluando Clase '7' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3833   14
# Real Sí     20   41
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 7       0.99      1.00      1.00      3847
#            7       0.75      0.67      0.71        61
#
#     accuracy                           0.99      3908
#    macro avg       0.87      0.83      0.85      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_7.png
#
# 🔍 Evaluando Clase '8' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3694   25
# Real Sí     66   123
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 8       0.98      0.99      0.99      3719
#            8       0.83      0.65      0.73       189
#
#     accuracy                           0.98      3908
#    macro avg       0.91      0.82      0.86      3908
# weighted avg       0.98      0.98      0.98      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_8.png
#
# 🔍 Evaluando Clase '9' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   10
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#         No 9       1.00      1.00      1.00      3906
#            9       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_9.png
#
# 🔍 Evaluando Clase '10' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3905   1
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 10       1.00      1.00      1.00      3906
#           10       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_10.png
#
# 🔍 Evaluando Clase '11' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3888   6
# Real Sí     7   7
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 11       1.00      1.00      1.00      3894
#           11       0.54      0.50      0.52        14
#
#     accuracy                           1.00      3908
#    macro avg       0.77      0.75      0.76      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_11.png
#
# 🔍 Evaluando Clase '12' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3859   11
# Real Sí     19   19
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 12       1.00      1.00      1.00      3870
#           12       0.63      0.50      0.56        38
#
#     accuracy                           0.99      3908
#    macro avg       0.81      0.75      0.78      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_12.png
#
# 🔍 Evaluando Clase '13' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3907   0
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 13       1.00      1.00      1.00      3907
#           13       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_13.png
#
# 🔍 Evaluando Clase '14' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3903   4
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 14       1.00      1.00      1.00      3907
#           14       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_14.png
#
# 🔍 Evaluando Clase '15' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3898   3
# Real Sí     5   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 15       1.00      1.00      1.00      3901
#           15       0.40      0.29      0.33         7
#
#     accuracy                           1.00      3908
#    macro avg       0.70      0.64      0.67      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_15.png
#
# 🔍 Evaluando Clase '16' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3901   3
# Real Sí     4   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 16       1.00      1.00      1.00      3904
#           16       0.00      0.00      0.00         4
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_16.png
#
# 🔍 Evaluando Clase '17' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3847   11
# Real Sí     10   40
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 17       1.00      1.00      1.00      3858
#           17       0.78      0.80      0.79        50
#
#     accuracy                           0.99      3908
#    macro avg       0.89      0.90      0.89      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_17.png
#
# 🔍 Evaluando Clase '18' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3890   8
# Real Sí     7   3
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 18       1.00      1.00      1.00      3898
#           18       0.27      0.30      0.29        10
#
#     accuracy                           1.00      3908
#    macro avg       0.64      0.65      0.64      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_18.png
#
# 🔍 Evaluando Clase '19' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3892   6
# Real Sí     5   5
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 19       1.00      1.00      1.00      3898
#           19       0.45      0.50      0.48        10
#
#     accuracy                           1.00      3908
#    macro avg       0.73      0.75      0.74      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_19.png
#
# 🔍 Evaluando Clase '20' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3905   1
# Real Sí     1   1
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 20       1.00      1.00      1.00      3906
#           20       0.50      0.50      0.50         2
#
#     accuracy                           1.00      3908
#    macro avg       0.75      0.75      0.75      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_20.png
#
# 🔍 Evaluando Clase '21' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3904   1
# Real Sí     3   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 21       1.00      1.00      1.00      3905
#           21       0.00      0.00      0.00         3
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_21.png
#
# 🔍 Evaluando Clase '22' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3900   6
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 22       1.00      1.00      1.00      3906
#           22       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_22.png
#
# 🔍 Evaluando Clase '23' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3901   0
# Real Sí     6   1
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 23       1.00      1.00      1.00      3901
#           23       1.00      0.14      0.25         7
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.57      0.62      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_23.png
#
# 🔍 Evaluando Clase '24' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3904   3
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 24       1.00      1.00      1.00      3907
#           24       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_24.png
#
# 🔍 Evaluando Clase '25' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3898   4
# Real Sí     6   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 25       1.00      1.00      1.00      3902
#           25       0.00      0.00      0.00         6
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_25.png
#
# 🔍 Evaluando Clase '26' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3902   4
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 26       1.00      1.00      1.00      3906
#           26       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_26.png
#
# 🔍 Evaluando Clase '27' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3903   3
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 27       1.00      1.00      1.00      3906
#           27       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_27.png
#
# 🔍 Evaluando Clase '28' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3898   4
# Real Sí     4   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 28       1.00      1.00      1.00      3902
#           28       0.33      0.33      0.33         6
#
#     accuracy                           1.00      3908
#    macro avg       0.67      0.67      0.67      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_28.png
#
# 🔍 Evaluando Clase '29' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3899   4
# Real Sí     3   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 29       1.00      1.00      1.00      3903
#           29       0.33      0.40      0.36         5
#
#     accuracy                           1.00      3908
#    macro avg       0.67      0.70      0.68      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_29.png
#
# 🔍 Evaluando Clase '30' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3901   3
# Real Sí     4   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 30       1.00      1.00      1.00      3904
#           30       0.00      0.00      0.00         4
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_30.png
#
# 🔍 Evaluando Clase '31' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3906   0
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 31       1.00      1.00      1.00      3906
#           31       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_31.png
#
# 🔍 Evaluando Clase '32' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3889   1
# Real Sí     2   16
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 32       1.00      1.00      1.00      3890
#           32       0.94      0.89      0.91        18
#
#     accuracy                           1.00      3908
#    macro avg       0.97      0.94      0.96      3908
# weighted avg       1.00      1.00      1.00      3908
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_32.png
#
# 🔍 Evaluando Clase '33' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3881   0
# Real Sí     11   16
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 33       1.00      1.00      1.00      3881
#           33       1.00      0.59      0.74        27
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.80      0.87      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_33.png
#
# 🔍 Evaluando Clase '34' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3907   0
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 34       1.00      1.00      1.00      3907
#           34       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_34.png
#
# 🔍 Evaluando Clase '35' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3906   0
# Real Sí     0   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 35       1.00      1.00      1.00      3906
#           35       1.00      1.00      1.00         2
#
#     accuracy                           1.00      3908
#    macro avg       1.00      1.00      1.00      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_35.png
#
# 🔍 Evaluando Clase '36' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3899   2
# Real Sí     1   6
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 36       1.00      1.00      1.00      3901
#           36       0.75      0.86      0.80         7
#
#     accuracy                           1.00      3908
#    macro avg       0.87      0.93      0.90      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_36.png
#
# 🔍 Evaluando Clase '37' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   1
# Real Sí     8   3
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 37       1.00      1.00      1.00      3897
#           37       0.75      0.27      0.40        11
#
#     accuracy                           1.00      3908
#    macro avg       0.87      0.64      0.70      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_37.png
#
# 🔍 Evaluando Clase '38' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3890   2
# Real Sí     14   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 38       1.00      1.00      1.00      3892
#           38       0.50      0.12      0.20        16
#
#     accuracy                           1.00      3908
#    macro avg       0.75      0.56      0.60      3908
# weighted avg       0.99      1.00      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_38.png
#
# 🔍 Evaluando Clase '39' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3827   12
# Real Sí     19   50
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 39       1.00      1.00      1.00      3839
#           39       0.81      0.72      0.76        69
#
#     accuracy                           0.99      3908
#    macro avg       0.90      0.86      0.88      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_39.png
#
# 🔍 Evaluando Clase '40' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3900   1
# Real Sí     4   3
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 40       1.00      1.00      1.00      3901
#           40       0.75      0.43      0.55         7
#
#     accuracy                           1.00      3908
#    macro avg       0.87      0.71      0.77      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_40.png
#
# 🔍 Evaluando Clase '41' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3807   7
# Real Sí     12   82
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 41       1.00      1.00      1.00      3814
#           41       0.92      0.87      0.90        94
#
#     accuracy                           1.00      3908
#    macro avg       0.96      0.94      0.95      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_41.png
#
# 🔍 Evaluando Clase '42' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3901   3
# Real Sí     2   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 42       1.00      1.00      1.00      3904
#           42       0.40      0.50      0.44         4
#
#     accuracy                           1.00      3908
#    macro avg       0.70      0.75      0.72      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_42.png
#
# 🔍 Evaluando Clase '43' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3902   2
# Real Sí     2   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 43       1.00      1.00      1.00      3904
#           43       0.50      0.50      0.50         4
#
#     accuracy                           1.00      3908
#    macro avg       0.75      0.75      0.75      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_43.png
#
# 🔍 Evaluando Clase '44' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3901   0
# Real Sí     1   6
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 44       1.00      1.00      1.00      3901
#           44       1.00      0.86      0.92         7
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.93      0.96      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_44.png
#
# 🔍 Evaluando Clase '45' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3894   2
# Real Sí     4   8
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 45       1.00      1.00      1.00      3896
#           45       0.80      0.67      0.73        12
#
#     accuracy                           1.00      3908
#    macro avg       0.90      0.83      0.86      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_45.png
#
# 🔍 Evaluando Clase '46' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3901   0
# Real Sí     4   3
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 46       1.00      1.00      1.00      3901
#           46       1.00      0.43      0.60         7
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.71      0.80      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_46.png
#
# 🔍 Evaluando Clase '47' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3892   1
# Real Sí     9   6
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 47       1.00      1.00      1.00      3893
#           47       0.86      0.40      0.55        15
#
#     accuracy                           1.00      3908
#    macro avg       0.93      0.70      0.77      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_47.png
#
# 🔍 Evaluando Clase '48' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3905   0
# Real Sí     1   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 48       1.00      1.00      1.00      3905
#           48       1.00      0.67      0.80         3
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.83      0.90      3908
# weighted avg       1.00      1.00      1.00      3908
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_48.png
#
# 🔍 Evaluando Clase '49' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3868   11
# Real Sí     20   9
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 49       0.99      1.00      1.00      3879
#           49       0.45      0.31      0.37        29
#
#     accuracy                           0.99      3908
#    macro avg       0.72      0.65      0.68      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_49.png
#
# 🔍 Evaluando Clase '50' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3711   32
# Real Sí     76   89
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 50       0.98      0.99      0.99      3743
#           50       0.74      0.54      0.62       165
#
#     accuracy                           0.97      3908
#    macro avg       0.86      0.77      0.80      3908
# weighted avg       0.97      0.97      0.97      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_50.png
#
# 🔍 Evaluando Clase '51' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3905   2
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 51       1.00      1.00      1.00      3907
#           51       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_51.png
#
# 🔍 Evaluando Clase '52' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3905   0
# Real Sí     1   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 52       1.00      1.00      1.00      3905
#           52       1.00      0.67      0.80         3
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.83      0.90      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_52.png
#
# 🔍 Evaluando Clase '53' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3900   1
# Real Sí     3   4
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 53       1.00      1.00      1.00      3901
#           53       0.80      0.57      0.67         7
#
#     accuracy                           1.00      3908
#    macro avg       0.90      0.79      0.83      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_53.png
#
# 🔍 Evaluando Clase '54' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3899   2
# Real Sí     0   7
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 54       1.00      1.00      1.00      3901
#           54       0.78      1.00      0.88         7
#
#     accuracy                           1.00      3908
#    macro avg       0.89      1.00      0.94      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_54.png
#
# 🔍 Evaluando Clase '55' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3845   5
# Real Sí     16   42
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 55       1.00      1.00      1.00      3850
#           55       0.89      0.72      0.80        58
#
#     accuracy                           0.99      3908
#    macro avg       0.94      0.86      0.90      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_55.png
#
# 🔍 Evaluando Clase '56' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3907   0
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 56       1.00      1.00      1.00      3907
#           56       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_56.png
#
# 🔍 Evaluando Clase '57' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3888   3
# Real Sí     5   12
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 57       1.00      1.00      1.00      3891
#           57       0.80      0.71      0.75        17
#
#     accuracy                           1.00      3908
#    macro avg       0.90      0.85      0.87      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_57.png
#
# 🔍 Evaluando Clase '58' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3907   0
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 58       1.00      1.00      1.00      3907
#           58       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_58.png
#
# 🔍 Evaluando Clase '59' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3902   1
# Real Sí     1   4
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 59       1.00      1.00      1.00      3903
#           59       0.80      0.80      0.80         5
#
#     accuracy                           1.00      3908
#    macro avg       0.90      0.90      0.90      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_59.png
#
# 🔍 Evaluando Clase '60' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3906   0
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 60       1.00      1.00      1.00      3906
#           60       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_60.png
#
# 🔍 Evaluando Clase '61' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3905   0
# Real Sí     3   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 61       1.00      1.00      1.00      3905
#           61       0.00      0.00      0.00         3
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_61.png
#
# 🔍 Evaluando Clase '62' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3821   9
# Real Sí     4   74
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 62       1.00      1.00      1.00      3830
#           62       0.89      0.95      0.92        78
#
#     accuracy                           1.00      3908
#    macro avg       0.95      0.97      0.96      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_62.png
#
# 🔍 Evaluando Clase '63' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3904   0
# Real Sí     0   4
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 63       1.00      1.00      1.00      3904
#           63       1.00      1.00      1.00         4
#
#     accuracy                           1.00      3908
#    macro avg       1.00      1.00      1.00      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_63.png
#
# 🔍 Evaluando Clase '64' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3901   0
# Real Sí     7   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 64       1.00      1.00      1.00      3901
#           64       0.00      0.00      0.00         7
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_64.png
#
# 🔍 Evaluando Clase '65' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3862   12
# Real Sí     17   17
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 65       1.00      1.00      1.00      3874
#           65       0.59      0.50      0.54        34
#
#     accuracy                           0.99      3908
#    macro avg       0.79      0.75      0.77      3908
# weighted avg       0.99      0.99      0.99      3908
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_65.png
#
# 🔍 Evaluando Clase '66' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3217   105
# Real Sí     190   396
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 66       0.94      0.97      0.96      3322
#           66       0.79      0.68      0.73       586
#
#     accuracy                           0.92      3908
#    macro avg       0.87      0.82      0.84      3908
# weighted avg       0.92      0.92      0.92      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_66.png
#
# 🔍 Evaluando Clase '67' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3898   0
# Real Sí     1   9
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 67       1.00      1.00      1.00      3898
#           67       1.00      0.90      0.95        10
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.95      0.97      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_67.png
#
# 🔍 Evaluando Clase '68' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   1
# Real Sí     1   10
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 68       1.00      1.00      1.00      3897
#           68       0.91      0.91      0.91        11
#
#     accuracy                           1.00      3908
#    macro avg       0.95      0.95      0.95      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_68.png
#
# 🔍 Evaluando Clase '69' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3891   4
# Real Sí     1   12
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 69       1.00      1.00      1.00      3895
#           69       0.75      0.92      0.83        13
#
#     accuracy                           1.00      3908
#    macro avg       0.87      0.96      0.91      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_69.png
#
# 🔍 Evaluando Clase '70' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3902   3
# Real Sí     3   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 70       1.00      1.00      1.00      3905
#           70       0.00      0.00      0.00         3
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_70.png
#
# 🔍 Evaluando Clase '71' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3873   0
# Real Sí     0   35
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 71       1.00      1.00      1.00      3873
#           71       1.00      1.00      1.00        35
#
#     accuracy                           1.00      3908
#    macro avg       1.00      1.00      1.00      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_71.png
#
# 🔍 Evaluando Clase '72' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3793   17
# Real Sí     36   62
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 72       0.99      1.00      0.99      3810
#           72       0.78      0.63      0.70        98
#
#     accuracy                           0.99      3908
#    macro avg       0.89      0.81      0.85      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_72.png
#
# 🔍 Evaluando Clase '73' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3849   9
# Real Sí     6   44
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 73       1.00      1.00      1.00      3858
#           73       0.83      0.88      0.85        50
#
#     accuracy                           1.00      3908
#    macro avg       0.91      0.94      0.93      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_73.png
#
# 🔍 Evaluando Clase '74' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3867   13
# Real Sí     13   15
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 74       1.00      1.00      1.00      3880
#           74       0.54      0.54      0.54        28
#
#     accuracy                           0.99      3908
#    macro avg       0.77      0.77      0.77      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_74.png
#
# 🔍 Evaluando Clase '75' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3791   21
# Real Sí     54   42
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 75       0.99      0.99      0.99      3812
#           75       0.67      0.44      0.53        96
#
#     accuracy                           0.98      3908
#    macro avg       0.83      0.72      0.76      3908
# weighted avg       0.98      0.98      0.98      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_75.png
#
# 🔍 Evaluando Clase '76' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3675   35
# Real Sí     99   99
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 76       0.97      0.99      0.98      3710
#           76       0.74      0.50      0.60       198
#
#     accuracy                           0.97      3908
#    macro avg       0.86      0.75      0.79      3908
# weighted avg       0.96      0.97      0.96      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_76.png
#
# 🔍 Evaluando Clase '77' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3883   3
# Real Sí     11   11
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 77       1.00      1.00      1.00      3886
#           77       0.79      0.50      0.61        22
#
#     accuracy                           1.00      3908
#    macro avg       0.89      0.75      0.80      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_77.png
#
# 🔍 Evaluando Clase '78' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3876   4
# Real Sí     6   22
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 78       1.00      1.00      1.00      3880
#           78       0.85      0.79      0.81        28
#
#     accuracy                           1.00      3908
#    macro avg       0.92      0.89      0.91      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_78.png
#
# 🔍 Evaluando Clase '79' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3581   43
# Real Sí     77   207
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 79       0.98      0.99      0.98      3624
#           79       0.83      0.73      0.78       284
#
#     accuracy                           0.97      3908
#    macro avg       0.90      0.86      0.88      3908
# weighted avg       0.97      0.97      0.97      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_79.png
#
# 🔍 Evaluando Clase '80' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   7
# Real Sí     3   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 80       1.00      1.00      1.00      3903
#           80       0.22      0.40      0.29         5
#
#     accuracy                           1.00      3908
#    macro avg       0.61      0.70      0.64      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_80.png
#
# 🔍 Evaluando Clase '81' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3864   20
# Real Sí     22   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 81       0.99      0.99      0.99      3884
#           81       0.09      0.08      0.09        24
#
#     accuracy                           0.99      3908
#    macro avg       0.54      0.54      0.54      3908
# weighted avg       0.99      0.99      0.99      3908
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_81.png
#
# 🔍 Evaluando Clase '82' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3877   0
# Real Sí     4   27
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 82       1.00      1.00      1.00      3877
#           82       1.00      0.87      0.93        31
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.94      0.97      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_82.png
#
# 🔍 Evaluando Clase '83' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3900   1
# Real Sí     0   7
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 83       1.00      1.00      1.00      3901
#           83       0.88      1.00      0.93         7
#
#     accuracy                           1.00      3908
#    macro avg       0.94      1.00      0.97      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_83.png
#
# 🔍 Evaluando Clase '84' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3889   1
# Real Sí     7   11
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 84       1.00      1.00      1.00      3890
#           84       0.92      0.61      0.73        18
#
#     accuracy                           1.00      3908
#    macro avg       0.96      0.81      0.87      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_84.png
#
# 🔍 Evaluando Clase '85' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3876   11
# Real Sí     10   11
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 85       1.00      1.00      1.00      3887
#           85       0.50      0.52      0.51        21
#
#     accuracy                           0.99      3908
#    macro avg       0.75      0.76      0.75      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_85.png
#
# 🔍 Evaluando Clase '86' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3622   35
# Real Sí     57   194
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 86       0.98      0.99      0.99      3657
#           86       0.85      0.77      0.81       251
#
#     accuracy                           0.98      3908
#    macro avg       0.92      0.88      0.90      3908
# weighted avg       0.98      0.98      0.98      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_86.png
#
# 🔍 Evaluando Clase '87' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3665   31
# Real Sí     43   169
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 87       0.99      0.99      0.99      3696
#           87       0.84      0.80      0.82       212
#
#     accuracy                           0.98      3908
#    macro avg       0.92      0.89      0.91      3908
# weighted avg       0.98      0.98      0.98      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_87.png
#
# 🔍 Evaluando Clase '88' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3887   0
# Real Sí     0   21
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 88       1.00      1.00      1.00      3887
#           88       1.00      1.00      1.00        21
#
#     accuracy                           1.00      3908
#    macro avg       1.00      1.00      1.00      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_88.png
#
# 🔍 Evaluando Clase '89' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   0
# Real Sí     2   10
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 89       1.00      1.00      1.00      3896
#           89       1.00      0.83      0.91        12
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.92      0.95      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_89.png
#
# 🔍 Evaluando Clase '90' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   0
# Real Sí     2   10
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 90       1.00      1.00      1.00      3896
#           90       1.00      0.83      0.91        12
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.92      0.95      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_90.png
#
# 🔍 Evaluando Clase '91' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3902   0
# Real Sí     1   5
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 91       1.00      1.00      1.00      3902
#           91       1.00      0.83      0.91         6
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.92      0.95      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_91.png
#
# 🔍 Evaluando Clase '92' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3890   6
# Real Sí     0   12
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 92       1.00      1.00      1.00      3896
#           92       0.67      1.00      0.80        12
#
#     accuracy                           1.00      3908
#    macro avg       0.83      1.00      0.90      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_92.png
#
# 🔍 Evaluando Clase '93' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3907   0
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 93       1.00      1.00      1.00      3907
#           93       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_93.png
#
# 🔍 Evaluando Clase '94' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3882   7
# Real Sí     19   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 94       1.00      1.00      1.00      3889
#           94       0.00      0.00      0.00        19
#
#     accuracy                           0.99      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_94.png
#
# 🔍 Evaluando Clase '95' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   1
# Real Sí     7   4
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 95       1.00      1.00      1.00      3897
#           95       0.80      0.36      0.50        11
#
#     accuracy                           1.00      3908
#    macro avg       0.90      0.68      0.75      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_95.png
#
# 🔍 Evaluando Clase '96' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3880   3
# Real Sí     8   17
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 96       1.00      1.00      1.00      3883
#           96       0.85      0.68      0.76        25
#
#     accuracy                           1.00      3908
#    macro avg       0.92      0.84      0.88      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_96.png
#
# 🔍 Evaluando Clase '97' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3403   504
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 97       1.00      0.87      0.93      3907
#           97       0.00      0.00      0.00         1
#
#     accuracy                           0.87      3908
#    macro avg       0.50      0.44      0.47      3908
# weighted avg       1.00      0.87      0.93      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_97.png
#
# 🔍 Evaluando Clase '98' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3907   0
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 98       1.00      1.00      1.00      3907
#           98       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_98.png
#
# 🔍 Evaluando Clase '99' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3885   3
# Real Sí     14   6
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#        No 99       1.00      1.00      1.00      3888
#           99       0.67      0.30      0.41        20
#
#     accuracy                           1.00      3908
#    macro avg       0.83      0.65      0.71      3908
# weighted avg       0.99      1.00      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_99.png
#
# 🔍 Evaluando Clase '100' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3903   1
# Real Sí     2   2
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 100       1.00      1.00      1.00      3904
#          100       0.67      0.50      0.57         4
#
#     accuracy                           1.00      3908
#    macro avg       0.83      0.75      0.79      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_100.png
#
# 🔍 Evaluando Clase '101' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3903   0
# Real Sí     5   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 101       1.00      1.00      1.00      3903
#          101       0.00      0.00      0.00         5
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_101.png
#
# 🔍 Evaluando Clase '102' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3818   14
# Real Sí     38   38
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 102       0.99      1.00      0.99      3832
#          102       0.73      0.50      0.59        76
#
#     accuracy                           0.99      3908
#    macro avg       0.86      0.75      0.79      3908
# weighted avg       0.99      0.99      0.99      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_102.png
#
# 🔍 Evaluando Clase '103' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3782   124
# Real Sí     1   1
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 103       1.00      0.97      0.98      3906
#          103       0.01      0.50      0.02         2
#
#     accuracy                           0.97      3908
#    macro avg       0.50      0.73      0.50      3908
# weighted avg       1.00      0.97      0.98      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_103.png
#
# 🔍 Evaluando Clase '104' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3907   0
# Real Sí     1   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 104       1.00      1.00      1.00      3907
#          104       0.00      0.00      0.00         1
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_104.png
#
# 🔍 Evaluando Clase '105' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3900   1
# Real Sí     0   7
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 105       1.00      1.00      1.00      3901
#          105       0.88      1.00      0.93         7
#
#     accuracy                           1.00      3908
#    macro avg       0.94      1.00      0.97      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_105.png
#
# 🔍 Evaluando Clase '106' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3906   0
# Real Sí     2   0
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 106       1.00      1.00      1.00      3906
#          106       0.00      0.00      0.00         2
#
#     accuracy                           1.00      3908
#    macro avg       0.50      0.50      0.50      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_106.png
#
# 🔍 Evaluando Clase '107' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3904   0
# Real Sí     1   3
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 107       1.00      1.00      1.00      3904
#          107       1.00      0.75      0.86         4
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.88      0.93      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_107.png
#
# 🔍 Evaluando Clase '108' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3876   10
# Real Sí     7   15
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 108       1.00      1.00      1.00      3886
#          108       0.60      0.68      0.64        22
#
#     accuracy                           1.00      3908
#    macro avg       0.80      0.84      0.82      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_108.png
#
# 🔍 Evaluando Clase '109' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3888   4
# Real Sí     11   5
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 109       1.00      1.00      1.00      3892
#          109       0.56      0.31      0.40        16
#
#     accuracy                           1.00      3908
#    macro avg       0.78      0.66      0.70      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_109.png
#
# 🔍 Evaluando Clase '110' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3890   0
# Real Sí     0   18
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 110       1.00      1.00      1.00      3890
#          110       1.00      1.00      1.00        18
#
#     accuracy                           1.00      3908
#    macro avg       1.00      1.00      1.00      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_110.png
#
# 🔍 Evaluando Clase '111' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3896   1
# Real Sí     4   7
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 111       1.00      1.00      1.00      3897
#          111       0.88      0.64      0.74        11
#
#     accuracy                           1.00      3908
#    macro avg       0.94      0.82      0.87      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_111.png
#
# 🔍 Evaluando Clase '112' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3863   0
# Real Sí     1   44
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 112       1.00      1.00      1.00      3863
#          112       1.00      0.98      0.99        45
#
#     accuracy                           1.00      3908
#    macro avg       1.00      0.99      0.99      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_112.png
#
# 🔍 Evaluando Clase '113' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3904   2
# Real Sí     1   1
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 113       1.00      1.00      1.00      3906
#          113       0.33      0.50      0.40         2
#
#     accuracy                           1.00      3908
#    macro avg       0.67      0.75      0.70      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_113.png
#
# 🔍 Evaluando Clase '114' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3862   5
# Real Sí     5   36
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 114       1.00      1.00      1.00      3867
#          114       0.88      0.88      0.88        41
#
#     accuracy                           1.00      3908
#    macro avg       0.94      0.94      0.94      3908
# weighted avg       1.00      1.00      1.00      3908
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_114.png
#
# 🔍 Evaluando Clase '115' (One-vs-Rest)
#                 Predicho
#                No    Sí
# Real No     3867   1
# Real Sí     11   29
#
# 📊 Métricas:
#               precision    recall  f1-score   support
#
#       No 115       1.00      1.00      1.00      3868
#          115       0.97      0.72      0.83        40
#
#     accuracy                           1.00      3908
#    macro avg       0.98      0.86      0.91      3908
# weighted avg       1.00      1.00      1.00      3908
#
# ✅ Imagen guardada en: matrices_binarias_ovr\matriz_binaria_clase_115.png

# %%
#nayve bayes
import numpy as np
import pandas as pd
import time
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    confusion_matrix, ConfusionMatrixDisplay,
    precision_score, recall_score, f1_score, accuracy_score
)
from imblearn.over_sampling import SMOTE, RandomOverSampler

# === 1. Datos ===
X = tfidf_dataframe_2.to_numpy()
y = data['SubRubro_encoded'].reset_index(drop=True)

# === 2. Modelo Naive Bayes con hiperparámetro ajustado ===
modelo = MultinomialNB(alpha=0.1)

# === 3. Validación cruzada ===
kf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

resultados = []
y_true_bin = []
y_pred_bin = []

inicio_total = time.time()

for fold, (train_idx, test_idx) in enumerate(kf.split(X, y), start=1):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    print(f"\nPliegue {fold}:")
    print(f"  Registros en entrenamiento: {len(X_train)}")
    print(f"  Registros en prueba:        {len(X_test)}")

    # === SMOTE o RandomOverSampler ===
    try:
        smote = SMOTE(k_neighbors=1, random_state=42)
        X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
        print(f"  Registros después de SMOTE: {len(X_train_res)}")
    except ValueError:
        print("⚠️ SMOTE no aplicable, usando RandomOverSampler")
        ros = RandomOverSampler(random_state=42)
        X_train_res, y_train_res = ros.fit_resample(X_train, y_train)

    # === Entrenamiento y predicción ===
    inicio = time.time()
    modelo.fit(X_train_res, y_train_res)
    y_pred = modelo.predict(X_test)
    fin = time.time()

    # === Métricas ===
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_test, y_pred, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_test, y_pred, average='weighted', zero_division=0)
    tiempo = fin - inicio

    resultados.append({
        'Pliegue': fold,
        'Accuracy': acc,
        'Precisión Weighted': prec,
        'Recall Macro': rec,
        'F1-Score Macro': f1_macro,
        'F1-Score Weighted': f1_weighted,
        'Tiempo (s)': tiempo
    })

    # Binaria: acierto (1) vs error (0)
    binaria = (y_pred == y_test).astype(int)
    y_true_bin.extend([1] * len(binaria))  # se espera acertar
    y_pred_bin.extend(binaria)

# === 4. Mostrar métricas ===
resultados_df = pd.DataFrame(resultados)
print("\n📊 Resultados por pliegue:")
print(resultados_df.round(4))

print("\n📈 Promedios globales:")
print(resultados_df.drop(columns="Pliegue").mean().to_frame().T.round(4))

fin_total = time.time()
print(f"\n⏱️ Tiempo total de ejecución: {round(fin_total - inicio_total, 2)} segundos")
# Out:
# Pliegue 1:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 2:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 3:
#   Registros en entrenamiento: 3126
#   Registros en prueba:        782
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 4:
#   Registros en entrenamiento: 3127
#   Registros en prueba:        781
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# Pliegue 5:
#   Registros en entrenamiento: 3127
#   Registros en prueba:        781
# ⚠️ SMOTE no aplicable, usando RandomOverSampler
#
# 📊 Resultados por pliegue:
#    Pliegue  Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0        1    0.6662              0.7494        0.5468          0.4786
# 1        2    0.6841              0.7583        0.5920          0.5267
# 2        3    0.6662              0.7674        0.5929          0.5140
# 3        4    0.6543              0.7513        0.5253          0.4824
# 4        5    0.6965              0.7751        0.5842          0.5238
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.6854      2.0460
# 1             0.7002      1.8504
# 2             0.6964      1.7894
# 3             0.6849      1.9390
# 4             0.7189      1.9563
#
# 📈 Promedios globales:
#    Accuracy  Precisión Weighted  Recall Macro  F1-Score Macro  \
# 0    0.6735              0.7603        0.5682          0.5051
#
#    F1-Score Weighted  Tiempo (s)
# 0             0.6972      1.9162
#
# ⏱️ Tiempo total de ejecución: 22.74 segundos
