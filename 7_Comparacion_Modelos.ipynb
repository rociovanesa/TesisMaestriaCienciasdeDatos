# %%
import pandas as pd
import matplotlib.pyplot as plt

# === 1. Crear el dataframe con las métricas ===
data_metricas = {
    "Modelo": ["Naive Bayes", "Regresión Logística", "Random Forest", "XGBoost", "SVM", "KNN"],
    "Accuracy": [0.6735, 0.7055, 0.7070, 0.6148, 0.6563, 0.5752],
    "Precisión Weighted": [0.7604, 0.7635, 0.7480, 0.7100, 0.7736, 0.7932],
    "Recall Macro": [0.5658, 0.5605, 0.5759, 0.5065, 0.5271, 0.4960],
    "F1-Score Macro": [0.5026, 0.5500, 0.5570, 0.5028, 0.5347, 0.5162],
    "F1-Score Weighted": [0.6970, 0.7246, 0.7184, 0.6474, 0.7000, 0.6453]
}

df_metricas = pd.DataFrame(data_metricas)
df_metricas.set_index("Modelo", inplace=True)

# === 2. Gráfico de barras agrupadas ===
plt.figure(figsize=(12, 6))
df_metricas.plot(kind='bar', figsize=(12, 6))

plt.title("Comparación de Métricas por Modelo")
plt.ylabel("Valor")
plt.ylim(0, 1)
plt.xticks(rotation=30)
plt.legend(title="Métrica", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# === 1. Datos de métricas por modelo ===
data_metricas = {
    "Modelo": ["Naive Bayes", "Regresión Logística", "Random Forest", "XGBoost", "SVM", "KNN"],
    "Accuracy": [0.6735, 0.7055, 0.7070, 0.6148, 0.6563, 0.5752],
    "Precisión Weighted": [0.7604, 0.7635, 0.7480, 0.7100, 0.7736, 0.7932],
    "Recall Macro": [0.5658, 0.5605, 0.5759, 0.5065, 0.5271, 0.4960],
    "F1-Score Macro": [0.5026, 0.5500, 0.5570, 0.5028, 0.5347, 0.5162],
    "F1-Score Weighted": [0.6970, 0.7246, 0.7184, 0.6474, 0.7000, 0.6453]
}

df_metricas = pd.DataFrame(data_metricas)
df_metricas.set_index("Modelo", inplace=True)

# === 2. Heatmap ===
plt.figure(figsize=(10, 6))
sns.heatmap(df_metricas, annot=True, fmt=".3f", cmap="Blues", cbar=True)

plt.title("Heatmap de Métricas por Modelo")
plt.ylabel("Modelo")
plt.xlabel("Métrica")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# === 1. Tiempos de entrenamiento (en segundos) ===
data_tiempos = {
    "Modelo": ["Naive Bayes", "Regresión Logística", "Random Forest", "XGBoost", "SVM", "KNN"],
    "Tiempo Total (s)": [18.1, 270481.42, 153.62, 4217.62, 2506.0, 34.59]
}

df_tiempos = pd.DataFrame(data_tiempos)
df_tiempos.set_index("Modelo", inplace=True)

# === 2. Gráfico de barras ===
plt.figure(figsize=(10, 5))
df_tiempos.plot(kind='bar', legend=False, color="steelblue")

plt.title("Tiempos de Entrenamiento por Modelo (segundos)")
plt.ylabel("Tiempo total (s)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# === 1. Datos de tiempo de entrenamiento (segundos) ===
data_tiempos = {
    "Modelo": ["Naive Bayes", "Regresión Logística", "Random Forest", "XGBoost", "SVM", "KNN"],
    "Tiempo Total (s)": [18.1, 270481.42, 153.62, 4217.62, 2506.0, 34.59]
}

df_tiempos = pd.DataFrame(data_tiempos)
df_tiempos.set_index("Modelo", inplace=True)

# === 2. Gráfico de barras con escala logarítmica ===
plt.figure(figsize=(10, 5))
ax = df_tiempos.plot(kind='bar', legend=False, color="mediumseagreen", logy=True)

plt.title("Tiempos de Entrenamiento por Modelo (escala logarítmica)")
plt.ylabel("Tiempo total (log s)")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# === 1. Datos de métricas por modelo ===
metricas = ["Accuracy", "Precisión Weighted", "Recall Macro", "F1-Score Macro", "F1-Score Weighted"]
modelos = ["Naive Bayes", "Regresión Logística", "Random Forest", "XGBoost", "SVM", "KNN"]

data = [
    [0.6735, 0.7604, 0.5658, 0.5026, 0.6970],  # Naive Bayes
    [0.7055, 0.7635, 0.5605, 0.5500, 0.7246],  # Regresión Logística
    [0.7070, 0.7480, 0.5759, 0.5570, 0.7184],  # Random Forest
    [0.6148, 0.7100, 0.5065, 0.5028, 0.6474],  # XGBoost
    [0.6563, 0.7736, 0.5271, 0.5347, 0.7000],  # SVM
    [0.5752, 0.7932, 0.4960, 0.5162, 0.6453]   # KNN
]

df = pd.DataFrame(data, columns=metricas, index=modelos)

# === 2. Preparar ángulos del gráfico ===
valores = df.values
n_metricas = len(metricas)
angles = np.linspace(0, 2 * np.pi, n_metricas, endpoint=False).tolist()
angles += angles[:1]  # cerrar el círculo

# === 3. Crear gráfico radar ===
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Graficar cada modelo
for i, modelo in enumerate(modelos):
    valores_modelo = valores[i].tolist()
    valores_modelo += valores_modelo[:1]  # cerrar
    ax.plot(angles, valores_modelo, label=modelo)
    ax.fill(angles, valores_modelo, alpha=0.1)

# Estética
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), metricas)
ax.set_ylim(0, 1)
plt.title("Comparación de Modelos - Gráfico Radar", size=14)
plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos
modelos = ["Naive Bayes", "Regresión Logística", "Random Forest", "XGBoost", "SVM", "KNN"]
tiempos = [18.1, 270481.42, 153.62, 4217.62, 2506.0, 34.59]  # Tiempo total (s)
f1_weighted = [0.6970, 0.7246, 0.7184, 0.6474, 0.7000, 0.6453]

# Crear gráfico
plt.figure(figsize=(10, 6))
plt.scatter(tiempos, f1_weighted, color="darkorange", s=100)

# Etiquetar cada punto
for i, modelo in enumerate(modelos):
    plt.text(tiempos[i], f1_weighted[i] + 0.002, modelo, fontsize=9, ha='center')

# Estética
plt.title("Tiempo de Entrenamiento vs. F1-Score Weighted")
plt.xlabel("Tiempo total (s)")
plt.ylabel("F1-Score Weighted")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Datos
modelos = ["Naive Bayes", "Regresión Logística", "Random Forest", "XGBoost", "SVM", "KNN"]
tiempos = [18.1, 270481.42, 153.62, 4217.62, 2506.0, 34.59]  # Tiempo total (s)
f1_weighted = [0.6970, 0.7246, 0.7184, 0.6474, 0.7000, 0.6453]

# Crear gráfico
plt.figure(figsize=(10, 6))
plt.scatter(tiempos, f1_weighted, color="darkorange", s=100)

# Etiquetar cada punto
for i, modelo in enumerate(modelos):
    plt.text(tiempos[i], f1_weighted[i] + 0.002, modelo, fontsize=9, ha='center')

# Estética
plt.title("Tiempo de Entrenamiento vs. F1-Score Weighted")
plt.xlabel("Tiempo total (s)")
plt.ylabel("F1-Score Weighted")
plt.grid(True)
plt.xscale("log")

plt.tight_layout()
plt.show()
